# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen
import logging

# %%
flipkart_url = "https://www.flipkart.com/search?q="+"mobile"

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=mobile'

# %%
url_client = urlopen(flipkart_url)

# %%
flipkart_page = url_client.read()

# %%
flipkart_page
# The reason we only get this is because the cursor of read opeartion is at thr end so we need to set it at the start to read again,
#so we need to execute above line once more
# Out:
# b''

# %%
#executing this line after executing urlopen() will set the cursor to first element and read all data
flipkart_html = bs(flipkart_page,'html.parser')

# %%
big_box = flipkart_html.find_all("div",{"class":"_1AtVbE col-12-12"})

# %%
len(big_box)
# Out:
# 30

# %%
shopclues_mob_url = "https://www.flipkart.com"+ big_box[0].a['href']

# %%
del big_box[0:3]

# %%
flipkart_mob_url = "https://www.flipkart.com"+big_box[0].div.div.div.a['href']

# %%
flipkart_mob_url
# Out:
# 'https://www.flipkart.com/poco-c50-royal-blue-32-gb/p/itma43af9d14952e?pid=MOBGK8WZUTGDEZFA&lid=LSTMOBGK8WZUTGDEZFAWKBDLT&marketplace=FLIPKART&q=mobile&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=8e37425e-5205-4174-b04b-6cdbd0015339.MOBGK8WZUTGDEZFA.SEARCH&ppt=None&ppn=None&ssid=hmwh0hska80000001694947800601&qH=532c28d5412dd75b'

# %%
big_box
# Out:
# [<div class="_1AtVbE col-12-12"><div class="_13oc-S"><div data-id="MOBGK8WZUTGDEZFA" style="width:100%"><div class="_2kHMtA"><a class="_1fQZEK" href="/poco-c50-royal-blue-32-gb/p/itma43af9d14952e?pid=MOBGK8WZUTGDEZFA&amp;lid=LSTMOBGK8WZUTGDEZFAWKBDLT&amp;marketplace=FLIPKART&amp;q=mobile&amp;store=tyy%2F4io&amp;srno=s_1_2&amp;otracker=search&amp;fm=organic&amp;iid=8e37425e-5205-4174-b04b-6cdbd0015339.MOBGK8WZUTGDEZFA.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=hmwh0hska80000001694947800601&amp;qH=532c28d5412dd75b" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="POCO C50 (Royal Blue, 32 GB)" class="_396cs4" loading="eager" src="https://rukminim2.flixcart.com/image/312/312/xif0q/mobile/t/a/x/-original-imaghmtch6qfmfxg.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><di
# ...

# %%
for i in big_box:
    print("https://www.flipkart.com"+i.div.div.div.a['href'])
# Out:
# https://www.flipkart.com/poco-c50-royal-blue-32-gb/p/itma43af9d14952e?pid=MOBGK8WZUTGDEZFA&lid=LSTMOBGK8WZUTGDEZFAWKBDLT&marketplace=FLIPKART&q=mobile&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=8e37425e-5205-4174-b04b-6cdbd0015339.MOBGK8WZUTGDEZFA.SEARCH&ppt=None&ppn=None&ssid=hmwh0hska80000001694947800601&qH=532c28d5412dd75b
# https://www.flipkart.com/poco-c51-royal-blue-64-gb/p/itm1e4e8373537a7?pid=MOBGZCQFCWNDK89P&lid=LSTMOBGZCQFCWNDK89POEPN6S&marketplace=FLIPKART&q=mobile&store=tyy%2F4io&srno=s_1_3&otracker=search&fm=organic&iid=8e37425e-5205-4174-b04b-6cdbd0015339.MOBGZCQFCWNDK89P.SEARCH&ppt=None&ppn=None&ssid=hmwh0hska80000001694947800601&qH=532c28d5412dd75b
# ...

# %%
prod_req = requests.get(flipkart_mob_url)

# %%
prod_html = bs(prod_req.text,'html.parser')

# %%
coment_box = prod_html.find_all("div",{"class":"_16PBlm"})

# %%
len(coment_box)
# Out:
# 11

# %%
coment_box[0].div

# %%
coment_box[0].div.div.find_all("p",{"class":"_2sc7ZR _2V5EHH"})[0].text
# Out:
# 'Parimal Mondal'

# %%
for i in coment_box:
    print(i.div.div.find_all("p",{"class":"_2sc7ZR _2V5EHH"})[0].text)
# Out:
# Parimal Mondal
# Flipkart Customer
# Jibrail  Alam
# Flipkart Customer
# Flipkart Customer
# Chirag Solanki
# Rameshwar kumar  Sahu
# Flipkart Customer
# Sumit Solanki
# Subham Sing
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[129], line 2
#       1 for i in coment_box:
# ----> 2     print(i.div.div.find_all("p",{"class":"_2sc7ZR _2V5EHH"})[0].text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
#for rating
coment_box[0].div.div.div.div.text
# Out:
# '5'

# %%
for i in coment_box:
    print(i.div.div.div.div.text)
# Out:
# 5
# 5
# 5
# 5
# 4
# 5
# 5
# 5
# 5
# 4
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[136], line 2
#       1 for i in coment_box:
# ----> 2     print(i.div.div.div.div.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
#for review
coment_box[0].div.div.div.p.text
# Out:
# 'Classy product'

# %%
for i in coment_box:
    print(i.div.div.div.p.text)
# Out:
# Classy product
# Perfect product!
# Terrific purchase
# Wonderful
# Pretty good
# Terrific
# Fabulous!
# Wonderful
# Classy product
# Pretty good
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[139], line 2
#       1 for i in coment_box:
# ----> 2     print(i.div.div.div.p.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
#finding what they wrote
coment_box[0].div.div.find_all("div",{"class":""})[0].text
# Out:
# 'Very good product ❤️👍READ MORE'

# %%
for i in coment_box:
    print(i.div.div.find_all("div",{"class":""})[0].text)
# Out:
# Very good product ❤️👍READ MORE
# Very good quality, thanks.READ MORE
# Good product 👍READ MORE
# Very niceREAD MORE
# Good product with good price...although front camera is ok while back camera is good..battery life is super.READ MORE
# for only who have limited budget... running smoothly for your daily life routine work ...🎈READ MORE
# Nice phoneREAD MORE
# SuperREAD MORE
# Initial impressions:- First up all at this price range it's really good value for money products 👌  I purchased it for my mom so she doesn't know much about android phone so not big expectations from her end regarding performance and etc... Thats why it' may be a decent choice .Pros* 1- Camera is decent 2- 5000 MAH Battery also good3- Display is decent 4- Sound quality is also good5- Look and design realy impressive. 6- processor is decent 7- stock android go edition with MIUI ...READ MORE
# Its good in this price rage...... stock andriod experience...❤️READ MORE
# ...
